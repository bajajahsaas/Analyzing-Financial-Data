# %%
import pandas as pd
import numpy as np
from scipy import stats
import seaborn as sn
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from regression import ridge_and_lasso, decision_trees, k_nearest_neighbors, linear_regression
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_regression, mutual_info_regression
from matplotlib import pyplot
from sklearn.feature_selection import SelectFromModel
from sklearn import preprocessing
from sklearn.preprocessing import OneHotEncoder
import copy
from sklearn.manifold import TSNE
import seaborn as sns

# %%
def read_data(filepath, use_industry=False, replace_with_mean=False):
    data = pd.read_excel(filepath, sheet_name = "Data", headers = None)
    data = data.set_index('tic')
    data.columns = data.columns.map(str)

    

    print('Original data shape: ', data.shape)

    # del columns with all NAN
    data = data.dropna(axis=1, how='all')

    # sector and industry can't be aggregated, drop if NAN
    data = data[pd.notnull(data['Sector'])]

    if use_industry:
        data = data[pd.notnull(data['Industry'])]

    print('Data after removing NAN sectors, industries ', data.shape)
    

    if replace_with_mean: 
        # replace with mean values
        print("Replacing empty cells with column means")
        for col in data.columns.to_list():
            if col == 'Sector':
                continue
            elif use_industry and col == 'Industry':
                continue
            data[col].fillna(data[col].mean(), inplace=True)

    # del rows with any NAN 
    data = data.dropna()

    print("Final Data: ", data.shape)


    # delete future sales predictions
    del data['St+1']
    del data['St']

    # Convert ordinal Sector into one-hot vectors
    data = pd.concat([data,pd.get_dummies(data['Sector'], prefix='Sector',dummy_na=False)],axis=1).drop(['Sector'],axis=1)

    if use_industry:
        # Convert ordinal Sector into one-hot vectors
        data = pd.concat([data,pd.get_dummies(data['Industry'], prefix='Industry',dummy_na=False)],axis=1).drop(['Industry'],axis=1)
    else:
        del data['Industry']

    return data

filepath = "../Sample.2.xlsx"
data = read_data(filepath)
data.head()
# Out:
# Original data shape:  (2559, 55)
# Data after removing NAN sectors, industries  (2396, 55)
# Final Data:  (1634, 55)
#          EMPLt     CPXt-1  GDWLt-1       GPt-1     OCFt-1      PPEt-1   RDt-1  \
# tic
# A      16300.0   156000.0  3590000   2790000.0  1020000.0    850000.0  404000
# AA     13800.0   379000.0   150000   1200000.0   686000.0   7920000.0   27000
# AAL   107400.0  4270000.0  4090000  11420000.0  3820000.0  43730000.0       0
# AAN    12100.0    92960.0   736580   1730000.0   441570.0    566880.0       0
# AAOI    3115.0    29430.0        0     45700.0     -858.0    256330.0   43400
#
#          SGAt-1        St-1     TEQt-1  ...  Sector_Communication Services  \
# tic                                     ...
# A     1860000.0   5160000.0  4750000.0  ...                              0
# AA     307000.0  10500000.0  4110000.0  ...                              0
# AAL   2000000.0  45770000.0  -118000.0  ...                              0
# AAN   1170000.0   3950000.0  1740000.0  ...                              0
# AAOI    94450.0    190870.0   273790.0  ...                              0
#
#       Sector_Consumer Cyclical  Sector_Consumer Defensive  Sector_Energy  \
# tic
# A                            0                          0              0
# AA                           0                          0              0
# AAL                          0                          0              0
# AAN                          0                          0              0
# AAOI                         0                          0              0
#
#       Sector_Financial Services  Sector_Healthcare  Sector_Industrials  \
# tic
# A                             0                  1                   0
# AA                            0                  0                   0
# AAL                           0                  0                   1
# AAN                           0                  0                   1
# AAOI                          0                  0                   0
#
#       Sector_Real Estate  Sector_Technology  Sector_Utilities
# tic
# A                      0                  0                 0
# AA                     0                  0                 0
# AAL                    0                  0                 0
# AAN                    0                  0                 0
# AAOI                   0                  1                 0
#
# [5 rows x 62 columns]

# %% [markdown]
# ### Using data from previous 2 yeara to predict Growth (St/St-1) using Xt-2 and Xt-3, predict separately each time. For year = 0, combine all data for multiple years and train a single predictor

# %%
def split_data(data, year):
    year_str = str(year)
    
    ys = []
    for y in year_str:
        ys.append(int(y))

    # to predict ys[0] , using ys[1:]
    
    
    year_cols = ['EMPLt']

    for col in data.columns.to_list():
        ismatch = False
        for y in ys[1:]:
            if col.endswith(str(y)): 
                ismatch = True
                break
        if ismatch or col.startswith('Sector') or col.startswith('Industry'):
           year_cols.append(col)

    # print(year, year_cols)
    year_df = data[year_cols].copy()
    year_df['Gt-' + str(ys[0])] = data['St-' + str(ys[0])] * 1.0 / data['St-' + str(ys[0] + 1)]


    print(year, year_df.columns.to_list())
    return year_df

years = [12345, 2345, 345, 45]
# year = 12345 means to predict Gt-1 using Xt-2, Xt-3, Xt-4, Xt-5

all_df = {}
for year in years:
    all_df[year] = split_data(data, year)
    print(year, all_df[year].shape)
# Out:
# 12345 ['EMPLt', 'CPXt-2', 'GDWLt-2', 'GPt-2', 'OCFt-2', 'PPEt-2', 'RDt-2', 'SGAt-2', 'St-2', 'TEQt-2', 'TDt-2', 'CPXt-3', 'GDWLt-3', 'GPt-3', 'OCFt-3', 'PPEt-3', 'RDt-3', 'SGAt-3', 'St-3', 'TEQt-3', 'TDt-3', 'CPXt-4', 'GDWLt-4', 'GPt-4', 'OCFt-4', 'PPEt-4', 'RDt-4', 'SGAt-4', 'St-4', 'TEQt-4', 'TDt-4', 'CPXt-5', 'GDWLt-5', 'GPt-5', 'OCFt-5', 'PPEt-5', 'RDt-5', 'SGAt-5', 'St-5', 'TEQt-5', 'TDt-5', 'Sector_Basic Materials', 'Sector_Communication Services', 'Sector_Consumer Cyclical', 'Sector_Consumer Defensive', 'Sector_Energy', 'Sector_Financial Services', 'Sector_Healthcare', 'Sector_Industrials', 'Sector_Real Estate', 'Sector_Technology', 'Sector_Utilities', 'Gt-1']
# 12345 (1634, 53)
# 2345 ['EMPLt', 'CPXt-3', 'GDWLt-3', 'GPt-3', 'OCFt-3', 'PPEt-3', 'RDt-3', 'SGAt-3', 'St-3', 'TEQt-3', 'TDt-3', 'CPXt-4', 'GDWLt-4', 'GPt-4', 'OCFt-4', 'PPEt-4', 'RDt-4', 'SGAt-4', 'St-4', 'TEQt-4', 'TDt-4', 'CPXt-5', 'GDWLt-5', 'GPt-5', 'OCFt-5', 'PPEt-5', 'RDt-5', 'SGAt-5', 'St-5', 'TEQt-5', 'TDt-5', 'Sector_Basic Materials', 'Sector_Communication Services', 'Sector_Consumer Cyclical', 'Sector_Consumer Defensive', 'Sector_Energy', 'Sector_Financial Services', 'Sector_Healthcare', 'Sector_Industrials', 'Sector_Real Estate', 'Sector_Technology', 'Sector_Utilities', 'Gt-2']
# 2345 (1634, 43)
# 345 ['EMPLt', 'CPXt-4', 'GDWLt-4', 'GPt-4', 'OCFt-4', 'PPEt-4', 'RDt-4', 'SGAt-4', 'St-4', 'TEQt-4', 'TDt-4', 'CPXt-5', 'GDWLt-5', 'GPt-5', 'OCFt-5', 'PPEt-5', 'RDt-5', 'SGAt-5', 'St-5', 'TEQt-5', 'TDt-5', 'Sector_Basic Materials', 'Sector_Communication Services', 'Sector_Consumer Cyclical', 'Sector_Consumer Defensive', 'Sector_Energy', 'Sector_Financial Services', 'Sector_Healthcare', 'Sector_Industrials', 'Sector_Real Estate', 'Sector_Technology', 'Sector_Utilities', 'Gt-3']
# 345 (1634, 33)
# 45 ['EMPLt', 'CPXt-5', 'GDWLt-5', 'GPt-5', 'OCFt-5', 'PPEt-5', 'RDt-5', 'SGAt-5', 'St-5', 'TEQt-5', 'TDt-5', 'Sector_Basic Materials', 'Sector_Communication Services', 'Sector_Consumer Cyclical', 'Sector_Consumer Defensive', 'Sector_Energy', 'Sector_Financial Services', 'Sector_Healthcare', 'Sector_Industrials', 'Sector_Real Estate', 'Sector_Technology', 'Sector_Utilities', 'Gt-4']
# 45 (1634, 23)

# %% [markdown]
# ## Regression Models

# %%
def prepare_data(X, year):
    
    year_str = str(year)

    ys = []
    for y in year_str:
        ys.append(int(y))

    X = X.reset_index()
    del X['tic']
    
    Y = X['Gt-' + str(ys[0])]
    del X['Gt-' + str(ys[0])]

    train_x, test_x, train_y, test_y = train_test_split(X, Y, shuffle=True, test_size=0.3, random_state=15)

    return train_x, train_y, test_x, test_y

# %%
scalers = {}

def standardize_data(train_x_df, train_y_df, test_x_df, test_y_df, year):
    # Requires numpy array for cross-validation in regression.py
    train_x = train_x_df.to_numpy()
    test_x = test_x_df.to_numpy()
    train_y = train_y_df.to_numpy()
    test_y = test_y_df.to_numpy()

    print('Train=', train_x.shape)
    print('Test=', test_x.shape)

    # normalize and scale data attributes
    # use only train_x for fitting
    # don't normalize, scale output variable

    scaler = preprocessing.MinMaxScaler().fit(train_x)

    train_x = scaler.transform(train_x)
    test_x = scaler.transform(test_x)

    # to be used later for query
    scalers[year] = scaler
    return train_x, train_y, test_x, test_y

# %%
train_x_dfs = {}
train_y_dfs = {}
test_x_dfs = {}
test_y_dfs = {}

train_xs = {}
train_ys = {}
test_xs = {}
test_ys= {}

for year in years:
    print('Preparing data for year: ', year)
    print(all_df[year].columns.to_list())
    train_x_dfs[year], train_y_dfs[year], test_x_dfs[year], test_y_dfs[year] = prepare_data(all_df[year], year)
    train_xs[year], train_ys[year], test_xs[year], test_ys[year] = standardize_data(train_x_dfs[year], train_y_dfs[year], test_x_dfs[year], test_y_dfs[year], year)
# Out:
# Preparing data for year:  12345
# ['EMPLt', 'CPXt-2', 'GDWLt-2', 'GPt-2', 'OCFt-2', 'PPEt-2', 'RDt-2', 'SGAt-2', 'St-2', 'TEQt-2', 'TDt-2', 'CPXt-3', 'GDWLt-3', 'GPt-3', 'OCFt-3', 'PPEt-3', 'RDt-3', 'SGAt-3', 'St-3', 'TEQt-3', 'TDt-3', 'CPXt-4', 'GDWLt-4', 'GPt-4', 'OCFt-4', 'PPEt-4', 'RDt-4', 'SGAt-4', 'St-4', 'TEQt-4', 'TDt-4', 'CPXt-5', 'GDWLt-5', 'GPt-5', 'OCFt-5', 'PPEt-5', 'RDt-5', 'SGAt-5', 'St-5', 'TEQt-5', 'TDt-5', 'Sector_Basic Materials', 'Sector_Communication Services', 'Sector_Consumer Cyclical', 'Sector_Consumer Defensive', 'Sector_Energy', 'Sector_Financial Services', 'Sector_Healthcare', 'Sector_Industrials', 'Sector_Real Estate', 'Sector_Technology', 'Sector_Utilities', 'Gt-1']
# Train= (1143, 52)
# Test= (491, 52)
# Preparing data for year:  2345
# ['EMPLt', 'CPXt-3', 'GDWLt-3', 'GPt-3', 'OCFt-3', 'PPEt-3', 'RDt-3', 'SGAt-3', 'St-3', 'TEQt-3', 'TDt-3', 'CPXt-4', 'GDWLt-4', 'GPt-4', 'OCFt-4', 'PPEt-4', 'RDt-4', 'SGAt-4', 'St-4', 'TEQt-4', 'TDt-4', 'CPXt-5', 'GDWLt-5', 'GPt-5', 'OCFt-5', 'PPEt-5', 'RDt-5', 'SGAt-5', 'St-5', 'TEQt-5', 'TDt-5', 'Sector_Basic Materials', 'Sector_Communication Services', 'Sector_Consumer Cyclical', 'Sector_Consumer Defensive', 'Sector_Energy', 'Sector_Financial Services', 'Sector_Healthcare', 'Sector_Industrials', 'Sector_Real Estate', 'Sector_Technology', 'Sector_Utilities', 'Gt-2']
# Train= (1143, 42)
# Test= (491, 42)
# Preparing data for year:  345
# ['EMPLt', 'CPXt-4', 'GDWLt-4', 'GPt-4', 'OCFt-4', 'PPEt-4', 'RDt-4', 'SGAt-4', 'St-4', 'TEQt-4', 'TDt-4', 'CPXt-5', 'GDWLt-5', 'GPt-5', 'OCFt-5', 'PPEt-5', 'RDt-5', 'SGAt-5', 'St-5', 'TEQt-5', 'TDt-5', 'Sector_Basic Materials', 'Sector_Communication Services', 'Sector_Consumer Cyclical', 'Sector_Consumer Defensive', 'Sector_Energy', 'Sector_Financial Services', 'Sector_Healthcare', 'Sector_Industrials', 'Sector_Real Estate', 'Sector_Technology', 'Sector_Utilities', 'Gt-3']
# Train= (1143, 32)
# Test= (491, 32)
# Preparing data for year:  45
# ['EMPLt', 'CPXt-5', 'GDWLt-5', 'GPt-5', 'OCFt-5', 'PPEt-5', 'RDt-5', 'SGAt-5', 'St-5', 'TEQt-5', 'TDt-5', 'Sector_Basic Materials', 'Sector_Communication Services', 'Sector_Consumer Cyclical', 'Sector_Consumer Defensive', 'Sector_Energy', 'Sector_Financial Services', 'Sector_Healthcare', 'Sector_Industrials', 'Sector_Real Estate', 'Sector_Technology', 'Sector_Utilities', 'Gt-4']
# Train= (1143, 22)
# Test= (491, 22)

# %% [markdown]
# ### Feature Selection

# %%
# feature selection
def select_features(X_train, y_train, X_test, mode):
    # configure to select all features
    if mode == 'f_regression':
        fs = SelectKBest(score_func=f_regression, k='all')
    elif mode == 'mutual_info_regression':
        fs = SelectKBest(score_func=mutual_info_regression, k='all')
    # learn relationship from training data
    X_train = X_train.astype(np.float64)
    y_train = y_train.astype(np.float64)
    X_test = X_test.astype(np.float64)
    fs.fit(X_train, y_train)
    # transform train input data
    X_train_fs = fs.transform(X_train)
    # transform test input data
    X_test_fs = fs.transform(X_test)
    
    return X_train_fs, X_test_fs, fs

modes = ['f_regression', 'mutual_info_regression']
for year in years:
    for mode in modes:
        # feature selection
        X_train_fs, X_test_fs, fs = select_features(train_x_dfs[year], train_y_dfs[year], test_x_dfs[year], mode)

        # what are scores for the features
        # for i in range(len(fs.scores_)):
        # 	print('Feature %d: %f' % (i, fs.scores_[i]))

        # plot the scores
        columns = train_x_dfs[year].columns.to_list()
        pyplot.xticks(rotation = (45), fontsize = 2)
        pyplot.bar([i for i in range(len(fs.scores_))], fs.scores_, tick_label=columns)
        pyplot.xlabel("Features")
        pyplot.ylabel("Important")
        pyplot.title("Year: {}, mode : {}".format(year, mode))
        pyplot.show()

# %% [markdown]
# ### Regression Model

# %%
# Compute MAE
def compute_error(y_hat, y):
    # mean absolute error
    return np.abs(y_hat - y).mean()

# Compute MSE
def compute_MSE(y, y_hat):
    # mean squared error
    return np.mean(np.power(y - y_hat, 2))

# %%
predicted_y  = {}
dt_model = {}
knn_model = {}
lr_model = {}
lm_model = {}

for year in years:
    metrics = ['mae', 'mse']
    models = ['dt', 'knn', 'lm', 'lr']
    print("\n")
    print("+++++++++++++")
    print("year: " + str(year))
    print("+++++++++++++")
    print(train_xs[year].shape, train_ys[year].shape, test_xs[year].shape)
    for model in models:
        if model == 'dt':
            predicted_y[year], dt_model[year] = decision_trees('A', train_xs[year], train_ys[year], test_xs[year])
        elif model =='knn':
            predicted_y[year], knn_model[year] = k_nearest_neighbors('A', train_xs[year], train_ys[year], test_xs[year])
        elif model =='lr':
            predicted_y[year], lr_model[year] = linear_regression('A', train_xs[year], train_ys[year], test_xs[year])
        elif model == 'lm':
            predicted_y[year], lm_model[year] = ridge_and_lasso('data', train_xs[year], train_ys[year], test_xs[year])
            
        for metric in metrics:
            if metric == 'mae':
                print('For year {}, MAE on test set: {:0.4f}'.format(str(year), compute_error(predicted_y[year], test_ys[year])))
            elif metric == 'mse':
                print('For year {}, MSE on test set: {:0.4f}'.format(str(year), compute_MSE(predicted_y[year], test_ys[year])))
# Out:
# +++++++++++++
# year: 12345
# +++++++++++++
# (1143, 52) (1143,) (491, 52)
# Running decision tree regressor for data type: A
# After cross-val, best depth for data A is 3 with mean Error: 0.1776
# Training model on full data
# For year 12345, MAE on test set: 0.1306
# For year 12345, MSE on test set: 0.0547
# Running k-nearest neighbor regressor for data type: A
# After cross-val, best neighbors for data A is 20 with mean Error: 0.1770
# Training model on full data
# For year 12345, MAE on test set: 0.1490
# For year 12345, MSE on test set: 0.0652
# Running ridge regressors for data type: data
# Running lasso regressors for data type: data
# After cross-val, best method for data data is lasso with alpha = 0.01 and mean Error: 0.1795
# Training model on full data
# For year 12345, MAE on test set: 0.1495
# For year 12345, MSE on test set: 0.0629
# Running linear regression for data type: A
# After cross-val for data A mean Error: 88424289113.4973
# Training model on full data
# For year 12345, MAE on test set: 0.1653
# For year 12345, MSE on test set: 0.0770
#
#
# +++++++++++++
# year: 2345
# +++++++++++++
# (1143, 42) (1143,) (491, 42)
# Running decision tree regressor for data type: A
# After cross-val, best depth for data A is 3 with mean Error: 0.1682
# Training model on full data
# For year 2345, MAE on test set: 0.1526
# For year 2345, MSE on test set: 0.0819
# Running k-nearest neighbor regressor for data type: A
# After cross-val, best neighbors for data A is 10 with mean Error: 0.1772
# Training model on full data
# For year 2345, MAE on test set: 0.1746
# For year 2345, MSE on test set: 0.1197
# Running ridge regressors for data type: data
# Running lasso regressors for data type: data
# After cross-val, best method for data data is ridge with alpha = 10 and mean Error: 0.1783
# Training model on full data
# For year 2345, MAE on test set: 0.1588
# For year 2345, MSE on test set: 0.0692
# Running linear regression for data type: A
# After cross-val for data A mean Error: 0.1987
# Training model on full data
# For year 2345, MAE on test set: 0.1672
# For year 2345, MSE on test set: 0.0728
#
#
# +++++++++++++
# year: 345
# +++++++++++++
# (1143, 32) (1143,) (491, 32)
# Running decision tree regressor for data type: A
# After cross-val, best depth for data A is 3 with mean Error: 0.2161
# Training model on full data
# For year 345, MAE on test set: 0.1737
# For year 345, MSE on test set: 0.2013
# Running k-nearest neighbor regressor for data type: A
# After cross-val, best neighbors for data A is 20 with mean Error: 0.2140
# Training model on full data
# For year 345, MAE on test set: 0.2134
# For year 345, MSE on test set: 0.2524
# Running ridge regressors for data type: data
# Running lasso regressors for data type: data
# After cross-val, best method for data data is ridge with alpha = 10 and mean Error: 0.2228
# Training model on full data
# For year 345, MAE on test set: 0.1970
# For year 345, MSE on test set: 0.2270
# Running linear regression for data type: A
# After cross-val for data A mean Error: 0.2366
# Training model on full data
# For year 345, MAE on test set: 0.1955
# For year 345, MSE on test set: 0.2263
#
#
# +++++++++++++
# year: 45
# +++++++++++++
# (1143, 22) (1143,) (491, 22)
# Running decision tree regressor for data type: A
# After cross-val, best depth for data A is 3 with mean Error: 0.2129
# Training model on full data
# For year 45, MAE on test set: 0.2210
# For year 45, MSE on test set: 0.5107
# Running k-nearest neighbor regressor for data type: A
# After cross-val, best neighbors for data A is 20 with mean Error: 0.2137
# Training model on full data
# For year 45, MAE on test set: 0.2401
# For year 45, MSE on test set: 0.5169
# Running ridge regressors for data type: data
# Running lasso regressors for data type: data
# After cross-val, best method for data data is lasso with alpha = 0.01 and mean Error: 0.2167
# Training model on full data
# For year 45, MAE on test set: 0.2386
# For year 45, MSE on test set: 0.5107
# Running linear regression for data type: A
# After cross-val for data A mean Error: 0.2242
# Training model on full data
# For year 45, MAE on test set: 0.2345
# For year 45, MSE on test set: 0.4988

# %%
# print('Printing Predictions')
# for y_hat, y in zip(predicted_y, test_y):
#     print(y, y_hat)

# %% [markdown]
# ### Feature Importance based on learned regressor

# %%
for year in years:
    print("\n")
    print("+++++++++++++")
    print("year: " + str(year))
    print("+++++++++++++")
    for model in [dt_model[year], lr_model[year], lm_model[year]]:
        print('\nModel : ', model)
        
        model_select = SelectFromModel(model, prefit=True)
        train_x_df_new = model_select.transform(train_x_dfs[year])
        print(train_x_dfs[year].shape, train_x_df_new.shape)

        feature_idx = model_select.get_support()
        feature_name = train_x_dfs[year].columns[feature_idx]
        print("Important Features: " ,feature_name)
# Out:
# +++++++++++++
# year: 12345
# +++++++++++++
#
# Model :  DecisionTreeRegressor(criterion='mae', max_depth=3)
# (1143, 52) (1143, 5)
# Important Features:  Index(['EMPLt', 'OCFt-2', 'RDt-5', 'St-5', 'Sector_Energy'], dtype='object')
#
# Model :  LinearRegression()
# (1143, 52) (1143, 11)
# Important Features:  Index(['Sector_Basic Materials', 'Sector_Communication Services',
#        'Sector_Consumer Cyclical', 'Sector_Consumer Defensive',
#        'Sector_Energy', 'Sector_Financial Services', 'Sector_Healthcare',
#        'Sector_Industrials', 'Sector_Real Estate', 'Sector_Technology',
#        'Sector_Utilities'],
#       dtype='object')
#
# Model :  Lasso(alpha=0.01)
# (1143, 52) (1143, 1)
# Important Features:  Index(['Sector_Healthcare'], dtype='object')
#
#
# +++++++++++++
# year: 2345
# +++++++++++++
#
# Model :  DecisionTreeRegressor(criterion='mae', max_depth=3)
# (1143, 42) (1143, 6)
# Important Features:  Index(['EMPLt', 'CPXt-3', 'OCFt-3', 'GPt-4', 'St-5', 'Sector_Energy'], dtype='object')
#
# Model :  LinearRegression()
# (1143, 42) (1143, 11)
# Important Features:  Index(['Sector_Basic Materials', 'Sector_Communication Services',
#        'Sector_Consumer Cyclical', 'Sector_Consumer Defensive',
#        'Sector_Energy', 'Sector_Financial Services', 'Sector_Healthcare',
#        'Sector_Industrials', 'Sector_Real Estate', 'Sector_Technology',
#        'Sector_Utilities'],
#       dtype='object')
#
# Model :  Ridge(alpha=10)
# (1143, 42) (1143, 17)
# Important Features:  Index(['EMPLt', 'CPXt-3', 'GDWLt-3', 'TDt-3', 'GDWLt-4', 'TDt-4', 'GDWLt-5',
#        'St-5', 'TDt-5', 'Sector_Basic Materials', 'Sector_Consumer Cyclical',
#        'Sector_Consumer Defensive', 'Sector_Energy',
#        'Sector_Financial Services', 'Sector_Healthcare', 'Sector_Industrials',
#        'Sector_Utilities'],
#       dtype='object')
#
#
# +++++++++++++
# year: 345
# +++++++++++++
#
# Model :  DecisionTreeRegressor(criterion='mae', max_depth=3)
# (1143, 32) (1143, 4)
# Important Features:  Index(['GPt-4', 'St-4', 'GDWLt-5', 'St-5'], dtype='object')
#
# Model :  LinearRegression()
# (1143, 32) (1143, 11)
# Important Features:  Index(['Sector_Basic Materials', 'Sector_Communication Services',
#        'Sector_Consumer Cyclical', 'Sector_Consumer Defensive',
#        'Sector_Energy', 'Sector_Financial Services', 'Sector_Healthcare',
#        'Sector_Industrials', 'Sector_Real Estate', 'Sector_Technology',
#        'Sector_Utilities'],
#       dtype='object')
#
# Model :  Ridge(alpha=10)
# (1143, 32) (1143, 11)
# Important Features:  Index(['TDt-4', 'GDWLt-5', 'SGAt-5', 'St-5', 'TDt-5', 'Sector_Basic Materials',
#        'Sector_Consumer Cyclical', 'Sector_Consumer Defensive',
#        'Sector_Energy', 'Sector_Healthcare', 'Sector_Industrials'],
#       dtype='object')
#
#
# +++++++++++++
# year: 45
# +++++++++++++
#
# Model :  DecisionTreeRegressor(criterion='mae', max_depth=3)
# (1143, 22) (1143, 4)
# Important Features:  Index(['EMPLt', 'PPEt-5', 'St-5', 'Sector_Energy'], dtype='object')
#
# Model :  LinearRegression()
# (1143, 22) (1143, 7)
# Important Features:  Index(['CPXt-5', 'GDWLt-5', 'GPt-5', 'PPEt-5', 'SGAt-5', 'TEQt-5', 'TDt-5'], dtype='object')
#
# Model :  Lasso(alpha=0.01)
# (1143, 22) (1143, 2)
# Important Features:  Index(['Sector_Energy', 'Sector_Healthcare'], dtype='object')
