# %%
import pandas as pd
import numpy as np
from scipy import stats
import seaborn as sn
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from regression import ridge_and_lasso, decision_trees, k_nearest_neighbors, linear_regression
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_regression, mutual_info_regression
from matplotlib import pyplot
from sklearn.feature_selection import SelectFromModel
from sklearn import preprocessing
from sklearn.preprocessing import OneHotEncoder
import copy
from sklearn.manifold import TSNE
import seaborn as sns

# %%
def read_data(filepath, use_industry=False, replace_with_mean=False):
    data = pd.read_excel(filepath, sheet_name = "Data", headers = None)
    data = data.set_index('tic')
    data.columns = data.columns.map(str)

    

    print('Original data shape: ', data.shape)

    # del columns with all NAN
    data = data.dropna(axis=1, how='all')

    # sector and industry can't be aggregated, drop if NAN
    data = data[pd.notnull(data['Sector'])]

    if use_industry:
        data = data[pd.notnull(data['Industry'])]

    print('Data after removing NAN sectors, industries ', data.shape)
    

    if replace_with_mean: 
        # replace with mean values
        print("Replacing empty cells with column means")
        for col in data.columns.to_list():
            if col == 'Sector':
                continue
            elif use_industry and col == 'Industry':
                continue
            data[col].fillna(data[col].mean(), inplace=True)

    # del rows with any NAN 
    data = data.dropna()

    print("Final Data: ", data.shape)


    # delete future sales predictions
    del data['St+1']
    del data['St']

    # Convert ordinal Sector into one-hot vectors
    data = pd.concat([data,pd.get_dummies(data['Sector'], prefix='Sector',dummy_na=False)],axis=1).drop(['Sector'],axis=1)

    if use_industry:
        # Convert ordinal Sector into one-hot vectors
        data = pd.concat([data,pd.get_dummies(data['Industry'], prefix='Industry',dummy_na=False)],axis=1).drop(['Industry'],axis=1)
    else:
        del data['Industry']

    return data

filepath = "../Sample.2.xlsx"
data = read_data(filepath)
data.head()
# Out:
# Original data shape:  (2559, 55)
# Data after removing NAN sectors, industries  (2396, 55)
# Final Data:  (1634, 55)
#          EMPLt     CPXt-1  GDWLt-1       GPt-1     OCFt-1      PPEt-1   RDt-1  \
# tic
# A      16300.0   156000.0  3590000   2790000.0  1020000.0    850000.0  404000
# AA     13800.0   379000.0   150000   1200000.0   686000.0   7920000.0   27000
# AAL   107400.0  4270000.0  4090000  11420000.0  3820000.0  43730000.0       0
# AAN    12100.0    92960.0   736580   1730000.0   441570.0    566880.0       0
# AAOI    3115.0    29430.0        0     45700.0     -858.0    256330.0   43400
#
#          SGAt-1        St-1     TEQt-1  ...  Sector_Communication Services  \
# tic                                     ...
# A     1860000.0   5160000.0  4750000.0  ...                              0
# AA     307000.0  10500000.0  4110000.0  ...                              0
# AAL   2000000.0  45770000.0  -118000.0  ...                              0
# AAN   1170000.0   3950000.0  1740000.0  ...                              0
# AAOI    94450.0    190870.0   273790.0  ...                              0
#
#       Sector_Consumer Cyclical  Sector_Consumer Defensive  Sector_Energy  \
# tic
# A                            0                          0              0
# AA                           0                          0              0
# AAL                          0                          0              0
# AAN                          0                          0              0
# AAOI                         0                          0              0
#
#       Sector_Financial Services  Sector_Healthcare  Sector_Industrials  \
# tic
# A                             0                  1                   0
# AA                            0                  0                   0
# AAL                           0                  0                   1
# AAN                           0                  0                   1
# AAOI                          0                  0                   0
#
#       Sector_Real Estate  Sector_Technology  Sector_Utilities
# tic
# A                      0                  0                 0
# AA                     0                  0                 0
# AAL                    0                  0                 0
# AAN                    0                  0                 0
# AAOI                   0                  1                 0
#
# [5 rows x 62 columns]

# %%
def split_data(data, year):
    year_cols = ['EMPLt']

    for col in data.columns.to_list():
        if col.endswith(str(year)) or col.startswith('Sector') or col.startswith('Industry'):
            year_cols.append(col)

    # print(year, year_cols)
    year_df = data[year_cols].copy()
    year_df['Gt-' + str(year)] = data['St-' + str(year)] * 1.0 / data['St-' + str(year + 1)]
    print(year, year_df.columns.to_list())

    # delete sales from training data as output_var is Gt
    del year_df['St-'+ str(year)]
    return year_df

years = [1, 2, 3, 4]
# year = 1 means to predict Gt-1 (St-1/St-2)

all_df = {}
for year in years:
    all_df[year] = split_data(data, year)
# Out:
# 1 ['EMPLt', 'CPXt-1', 'GDWLt-1', 'GPt-1', 'OCFt-1', 'PPEt-1', 'RDt-1', 'SGAt-1', 'St-1', 'TEQt-1', 'TDt-1', 'Sector_Basic Materials', 'Sector_Communication Services', 'Sector_Consumer Cyclical', 'Sector_Consumer Defensive', 'Sector_Energy', 'Sector_Financial Services', 'Sector_Healthcare', 'Sector_Industrials', 'Sector_Real Estate', 'Sector_Technology', 'Sector_Utilities', 'Gt-1']
# 2 ['EMPLt', 'CPXt-2', 'GDWLt-2', 'GPt-2', 'OCFt-2', 'PPEt-2', 'RDt-2', 'SGAt-2', 'St-2', 'TEQt-2', 'TDt-2', 'Sector_Basic Materials', 'Sector_Communication Services', 'Sector_Consumer Cyclical', 'Sector_Consumer Defensive', 'Sector_Energy', 'Sector_Financial Services', 'Sector_Healthcare', 'Sector_Industrials', 'Sector_Real Estate', 'Sector_Technology', 'Sector_Utilities', 'Gt-2']
# 3 ['EMPLt', 'CPXt-3', 'GDWLt-3', 'GPt-3', 'OCFt-3', 'PPEt-3', 'RDt-3', 'SGAt-3', 'St-3', 'TEQt-3', 'TDt-3', 'Sector_Basic Materials', 'Sector_Communication Services', 'Sector_Consumer Cyclical', 'Sector_Consumer Defensive', 'Sector_Energy', 'Sector_Financial Services', 'Sector_Healthcare', 'Sector_Industrials', 'Sector_Real Estate', 'Sector_Technology', 'Sector_Utilities', 'Gt-3']
# 4 ['EMPLt', 'CPXt-4', 'GDWLt-4', 'GPt-4', 'OCFt-4', 'PPEt-4', 'RDt-4', 'SGAt-4', 'St-4', 'TEQt-4', 'TDt-4', 'Sector_Basic Materials', 'Sector_Communication Services', 'Sector_Consumer Cyclical', 'Sector_Consumer Defensive', 'Sector_Energy', 'Sector_Financial Services', 'Sector_Healthcare', 'Sector_Industrials', 'Sector_Real Estate', 'Sector_Technology', 'Sector_Utilities', 'Gt-4']

# %% [markdown]
# ## Regression Models

# %%
def prepare_data(X, year):
    X = X.reset_index()
    del X['tic']
    
    Y = X['Gt-' + str(year)]
    del X['Gt-' + str(year)]
    train_x, test_x, train_y, test_y = train_test_split(X, Y, shuffle=True, test_size=0.3, random_state=15)

    return train_x, train_y, test_x, test_y

# %%
def standardize_data(train_x_df, train_y_df, test_x_df, test_y_df):
    # Requires numpy array for cross-validation in regression.py
    train_x = train_x_df.to_numpy()
    test_x = test_x_df.to_numpy()
    train_y = train_y_df.to_numpy()
    test_y = test_y_df.to_numpy()

    print('Train=', train_x.shape)
    print('Test=', test_x.shape)

    # normalize and scale data attributes
    # use only train_x for fitting
    # don't normalize, scale output variable

    scaler = preprocessing.MinMaxScaler().fit(train_x)

    train_x = scaler.transform(train_x)
    test_x = scaler.transform(test_x)

    return train_x, train_y, test_x, test_y

# %%
train_x_dfs = {}
train_y_dfs = {}
test_x_dfs = {}
test_y_dfs = {}

train_xs = {}
train_ys = {}
test_xs = {}
test_ys= {}

for year in years:
    train_x_dfs[year], train_y_dfs[year], test_x_dfs[year], test_y_dfs[year] = prepare_data(all_df[year], year)
    train_xs[year], train_ys[year], test_xs[year], test_ys[year] = standardize_data(train_x_dfs[year], train_y_dfs[year], test_x_dfs[year], test_y_dfs[year])
# Out:
# Train= (1143, 21)
# Test= (491, 21)
# Train= (1143, 21)
# Test= (491, 21)
# Train= (1143, 21)
# Test= (491, 21)
# Train= (1143, 21)
# Test= (491, 21)

# %% [markdown]
# ### Feature Selection

# %%
# feature selection
def select_features(X_train, y_train, X_test, mode):
    # configure to select all features
    if mode == 'f_regression':
        fs = SelectKBest(score_func=f_regression, k='all')
    elif mode == 'mutual_info_regression':
        fs = SelectKBest(score_func=mutual_info_regression, k='all')
    # learn relationship from training data
    X_train = X_train.astype(np.float64)
    y_train = y_train.astype(np.float64)
    X_test = X_test.astype(np.float64)
    fs.fit(X_train, y_train)
    # transform train input data
    X_train_fs = fs.transform(X_train)
    # transform test input data
    X_test_fs = fs.transform(X_test)
    
    return X_train_fs, X_test_fs, fs

modes = ['f_regression', 'mutual_info_regression']
for year in years:
    for mode in modes:
        # feature selection
        X_train_fs, X_test_fs, fs = select_features(train_x_dfs[year], train_y_dfs[year], test_x_dfs[year], mode)

        # what are scores for the features
        # for i in range(len(fs.scores_)):
        # 	print('Feature %d: %f' % (i, fs.scores_[i]))

        # plot the scores
        columns = train_x_dfs[year].columns.to_list()
        pyplot.xticks(rotation = (45), fontsize = 2)
        pyplot.bar([i for i in range(len(fs.scores_))], fs.scores_, tick_label=columns)
        pyplot.xlabel("Features")
        pyplot.ylabel("Important")
        pyplot.title("Year: {}, mode : {}".format(year, mode))
        pyplot.show()

# %% [markdown]
# ### Regression Model

# %%
# Compute MAE
def compute_error(y_hat, y):
    # mean absolute error
    return np.abs(y_hat - y).mean()

# Compute MSE
def compute_MSE(y, y_hat):
    # mean squared error
    return np.mean(np.power(y - y_hat, 2))

# %%
for year in years:
    metrics = ['mae', 'mse']
    models = ['dt', 'knn', 'lm', 'lr']

    print(train_xs[year].shape, train_ys[year].shape, test_xs[year].shape)
    for model in models:
        if model == 'dt':
            predicted_y, dt_model = decision_trees('A', train_xs[year], train_ys[year], test_xs[year])
        elif model =='knn':
            predicted_y, knn_model = k_nearest_neighbors('A', train_xs[year], train_ys[year], test_xs[year])
        elif model =='lr':
            predicted_y, lr_model = linear_regression('A', train_xs[year], train_ys[year], test_xs[year])
        elif model == 'lm':
            predicted_y, lm_model = ridge_and_lasso('data', train_xs[year], train_ys[year], test_xs[year])
            
        for metric in metrics:
            if metric == 'mae':
                print('For year {}, MAE on test set: {:0.4f}'.format(str(year), compute_error(predicted_y, test_y)))
            elif metric == 'mse':
                print('For year {}, MSE on test set: {:0.4f}'.format(str(year), compute_MSE(predicted_y, test_y)))
# Out:
# (1143, 21) (1143,) (491, 21)
# Running decision tree regressor for data type: A
# Mean error for data A and hyperparameter 3: 0.1663
# --- 332 milli-seconds ---
# Mean error for data A and hyperparameter 6: 0.2203
# --- 480 milli-seconds ---
# Mean error for data A and hyperparameter 9: 0.2574
# --- 585 milli-seconds ---
# Mean error for data A and hyperparameter 12: 0.2584
# --- 649 milli-seconds ---
# Mean error for data A and hyperparameter 15: 0.2636
# --- 693 milli-seconds ---
# Mean error for data A and hyperparameter 20: 0.2988
# --- 734 milli-seconds ---
# Mean error for data A and hyperparameter 25: 0.2738
# --- 750 milli-seconds ---
# Mean error for data A and hyperparameter 30: 0.2787
# --- 790 milli-seconds ---
# Mean error for data A and hyperparameter 35: 0.2918
# --- 781 milli-seconds ---
# Mean error for data A and hyperparameter 40: 0.2790
# --- 768 milli-seconds ---
# After cross-val, best depth for data A is 3 with mean Error: 0.1663
# Training model on full data
# For year 1, MAE on test set: 0.1359
# For year 1, MSE on test set: 0.0663
# Running k-nearest neighbor regressor for data type: A
# Mean error for data A and hyperparameter 3: 0.2113
# --- 25 milli-seconds ---
# Mean error for data A and hyperparameter 5: 0.2027
# --- 27 milli-seconds ---
# Mean error for data A and hyperparameter 10: 0.1925
# --- 31 milli-seconds ---
# Mean error for data A and hyperparameter 20: 0.1903
# --- 34 milli-seconds ---
# Mean error for data A and hyperparameter 25: 0.1864
# --- 35 milli-seconds ---
# After cross-val, best neighbors for data A is 25 with mean Error: 0.1864
# Training model on full data
# For year 1, MAE on test set: 0.1519
# For year 1, MSE on test set: 0.0677
# Running ridge regressors for data type: data
# Mean error for data data and hyperparameter 1e-06: 0.1849
# --- 5 milli-seconds ---
# Mean error for data data and hyperparameter 0.0001: 0.1849
# --- 4 milli-seconds ---
# Mean error for data data and hyperparameter 0.01: 0.1847
# --- 5 milli-seconds ---
# Mean error for data data and hyperparameter 1: 0.1824
# --- 6 milli-seconds ---
# Mean error for data data and hyperparameter 10: 0.1811
# --- 6 milli-seconds ---
# Running lasso regressors for data type: data
# Mean error for data data and hyperparameter 1e-06: 0.1848
# --- 79 milli-seconds ---
# Mean error for data data and hyperparameter 0.0001: 0.1830
# --- 8 milli-seconds ---
# Mean error for data data and hyperparameter 0.01: 0.1795
# --- 5 milli-seconds ---
# Mean error for data data and hyperparameter 1: 0.1800
# --- 6 milli-seconds ---
# Mean error for data data and hyperparameter 10: 0.1800
# --- 5 milli-seconds ---
# After cross-val, best method for data data is lasso with alpha = 0.01 and mean Error: 0.1795
# Training model on full data
# For year 1, MAE on test set: 0.1495
# For year 1, MSE on test set: 0.0629
# Running linear regression for data type: A
# Mean error for data A and hyperparameter None: 0.1849
# --- 7 milli-seconds ---
# After cross-val for data A mean Error: 0.1849
# Training model on full data
# For year 1, MAE on test set: 0.1544
# For year 1, MSE on test set: 0.0643
# (1143, 21) (1143,) (491, 21)
# Running decision tree regressor for data type: A
# Mean error for data A and hyperparameter 3: 0.1680
# --- 414 milli-seconds ---
# Mean error for data A and hyperparameter 6: 0.1793
# --- 607 milli-seconds ---
# Mean error for data A and hyperparameter 9: 0.1943
# --- 741 milli-seconds ---
# Mean error for data A and hyperparameter 12: 0.2116
# --- 831 milli-seconds ---
# Mean error for data A and hyperparameter 15: 0.2176
# --- 901 milli-seconds ---
# Mean error for data A and hyperparameter 20: 0.2302
# --- 963 milli-seconds ---
# Mean error for data A and hyperparameter 25: 0.2368
# --- 992 milli-seconds ---
# Mean error for data A and hyperparameter 30: 0.2401
# --- 1003 milli-seconds ---
# Mean error for data A and hyperparameter 35: 0.2429
# --- 1001 milli-seconds ---
# Mean error for data A and hyperparameter 40: 0.2435
# --- 1005 milli-seconds ---
# After cross-val, best depth for data A is 3 with mean Error: 0.1680
# Training model on full data
# For year 2, MAE on test set: 0.1473
# For year 2, MSE on test set: 0.0667
# Running k-nearest neighbor regressor for data type: A
# Mean error for data A and hyperparameter 3: 0.1933
# --- 35 milli-seconds ---
# Mean error for data A and hyperparameter 5: 0.1942
# --- 39 milli-seconds ---
# Mean error for data A and hyperparameter 10: 0.1887
# --- 29 milli-seconds ---
# Mean error for data A and hyperparameter 20: 0.1835
# --- 34 milli-seconds ---
# Mean error for data A and hyperparameter 25: 0.1818
# --- 36 milli-seconds ---
# After cross-val, best neighbors for data A is 25 with mean Error: 0.1818
# Training model on full data
# For year 2, MAE on test set: 0.1663
# For year 2, MSE on test set: 0.0685
# Running ridge regressors for data type: data
# Mean error for data data and hyperparameter 1e-06: 0.1804
# --- 5 milli-seconds ---
# Mean error for data data and hyperparameter 0.0001: 0.1804
# --- 5 milli-seconds ---
# Mean error for data data and hyperparameter 0.01: 0.1801
# --- 5 milli-seconds ---
# Mean error for data data and hyperparameter 1: 0.1791
# --- 5 milli-seconds ---
# Mean error for data data and hyperparameter 10: 0.1788
# --- 4 milli-seconds ---
# Running lasso regressors for data type: data
# Mean error for data data and hyperparameter 1e-06: 0.1803
# --- 76 milli-seconds ---
# Mean error for data data and hyperparameter 0.0001: 0.1803
# --- 12 milli-seconds ---
# Mean error for data data and hyperparameter 0.01: 0.1807
# --- 5 milli-seconds ---
# Mean error for data data and hyperparameter 1: 0.1815
# --- 5 milli-seconds ---
# Mean error for data data and hyperparameter 10: 0.1815
# --- 6 milli-seconds ---
# After cross-val, best method for data data is ridge with alpha = 10 and mean Error: 0.1788
# Training model on full data
# For year 2, MAE on test set: 0.1651
# For year 2, MSE on test set: 0.0665
# Running linear regression for data type: A
# Mean error for data A and hyperparameter None: 0.1805
# --- 7 milli-seconds ---
# After cross-val for data A mean Error: 0.1805
# Training model on full data
# For year 2, MAE on test set: 0.1693
# For year 2, MSE on test set: 0.0705
# (1143, 21) (1143,) (491, 21)
# Running decision tree regressor for data type: A
# Mean error for data A and hyperparameter 3: 0.2144
# --- 397 milli-seconds ---
# Mean error for data A and hyperparameter 6: 0.2240
# --- 542 milli-seconds ---
# Mean error for data A and hyperparameter 9: 0.2628
# --- 662 milli-seconds ---
# Mean error for data A and hyperparameter 12: 0.2753
# --- 749 milli-seconds ---
# Mean error for data A and hyperparameter 15: 0.2983
# --- 804 milli-seconds ---
# Mean error for data A and hyperparameter 20: 0.2997
# --- 864 milli-seconds ---
# Mean error for data A and hyperparameter 25: 0.3223
# --- 885 milli-seconds ---
# Mean error for data A and hyperparameter 30: 0.3247
# --- 890 milli-seconds ---
# Mean error for data A and hyperparameter 35: 0.3257
# --- 897 milli-seconds ---
# Mean error for data A and hyperparameter 40: 0.3316
# --- 895 milli-seconds ---
# After cross-val, best depth for data A is 3 with mean Error: 0.2144
# Training model on full data
# For year 3, MAE on test set: 0.1466
# For year 3, MSE on test set: 0.0698
# Running k-nearest neighbor regressor for data type: A
# Mean error for data A and hyperparameter 3: 0.2312
# --- 25 milli-seconds ---
# Mean error for data A and hyperparameter 5: 0.2367
# --- 27 milli-seconds ---
# Mean error for data A and hyperparameter 10: 0.2272
# --- 29 milli-seconds ---
# Mean error for data A and hyperparameter 20: 0.2196
# --- 32 milli-seconds ---
# Mean error for data A and hyperparameter 25: 0.2205
# --- 35 milli-seconds ---
# After cross-val, best neighbors for data A is 20 with mean Error: 0.2196
# Training model on full data
# For year 3, MAE on test set: 0.1993
# For year 3, MSE on test set: 0.1285
# Running ridge regressors for data type: data
# Mean error for data data and hyperparameter 1e-06: 0.2298
# --- 6 milli-seconds ---
# Mean error for data data and hyperparameter 0.0001: 0.2298
# --- 4 milli-seconds ---
# Mean error for data data and hyperparameter 0.01: 0.2288
# --- 6 milli-seconds ---
# Mean error for data data and hyperparameter 1: 0.2241
# --- 4 milli-seconds ---
# Mean error for data data and hyperparameter 10: 0.2230
# --- 5 milli-seconds ---
# Running lasso regressors for data type: data
# Mean error for data data and hyperparameter 1e-06: 0.2297
# --- 72 milli-seconds ---
# Mean error for data data and hyperparameter 0.0001: 0.2259
# --- 13 milli-seconds ---
# Mean error for data data and hyperparameter 0.01: 0.2251
# --- 5 milli-seconds ---
# Mean error for data data and hyperparameter 1: 0.2243
# --- 6 milli-seconds ---
# Mean error for data data and hyperparameter 10: 0.2243
# --- 6 milli-seconds ---
# After cross-val, best method for data data is ridge with alpha = 10 and mean Error: 0.2230
# Training model on full data
# For year 3, MAE on test set: 0.1816
# For year 3, MSE on test set: 0.0716
# Running linear regression for data type: A
# Mean error for data A and hyperparameter None: 0.2296
# --- 7 milli-seconds ---
# After cross-val for data A mean Error: 0.2296
# Training model on full data
# For year 3, MAE on test set: 0.1823
# For year 3, MSE on test set: 0.0726
# (1143, 21) (1143,) (491, 21)
# Running decision tree regressor for data type: A
# Mean error for data A and hyperparameter 3: 0.2136
# --- 385 milli-seconds ---
# Mean error for data A and hyperparameter 6: 0.2556
# --- 540 milli-seconds ---
# Mean error for data A and hyperparameter 9: 0.3098
# --- 654 milli-seconds ---
# Mean error for data A and hyperparameter 12: 0.3271
# --- 731 milli-seconds ---
# Mean error for data A and hyperparameter 15: 0.3306
# --- 757 milli-seconds ---
# Mean error for data A and hyperparameter 20: 0.3429
# --- 796 milli-seconds ---
# Mean error for data A and hyperparameter 25: 0.3614
# --- 809 milli-seconds ---
# Mean error for data A and hyperparameter 30: 0.3411
# --- 812 milli-seconds ---
# Mean error for data A and hyperparameter 35: 0.3557
# --- 817 milli-seconds ---
# Mean error for data A and hyperparameter 40: 0.3507
# --- 818 milli-seconds ---
# After cross-val, best depth for data A is 3 with mean Error: 0.2136
# Training model on full data
# For year 4, MAE on test set: 0.1357
# For year 4, MSE on test set: 0.0601
# Running k-nearest neighbor regressor for data type: A
# Mean error for data A and hyperparameter 3: 0.2533
# --- 25 milli-seconds ---
# Mean error for data A and hyperparameter 5: 0.2391
# --- 27 milli-seconds ---
# Mean error for data A and hyperparameter 10: 0.2307
# --- 28 milli-seconds ---
# Mean error for data A and hyperparameter 20: 0.2157
# --- 33 milli-seconds ---
# Mean error for data A and hyperparameter 25: 0.2159
# --- 35 milli-seconds ---
# After cross-val, best neighbors for data A is 20 with mean Error: 0.2157
# Training model on full data
# For year 4, MAE on test set: 0.1688
# For year 4, MSE on test set: 0.0727
# Running ridge regressors for data type: data
# Mean error for data data and hyperparameter 1e-06: 0.2239
# --- 5 milli-seconds ---
# Mean error for data data and hyperparameter 0.0001: 0.2238
# --- 5 milli-seconds ---
# Mean error for data data and hyperparameter 0.01: 0.2218
# --- 5 milli-seconds ---
# Mean error for data data and hyperparameter 1: 0.2185
# --- 5 milli-seconds ---
# Mean error for data data and hyperparameter 10: 0.2169
# --- 5 milli-seconds ---
# Running lasso regressors for data type: data
# Mean error for data data and hyperparameter 1e-06: 0.2237
# --- 72 milli-seconds ---
# Mean error for data data and hyperparameter 0.0001: 0.2192
# --- 12 milli-seconds ---
# Mean error for data data and hyperparameter 0.01: 0.2167
# --- 5 milli-seconds ---
# Mean error for data data and hyperparameter 1: 0.2230
# --- 5 milli-seconds ---
# Mean error for data data and hyperparameter 10: 0.2230
# --- 6 milli-seconds ---
# After cross-val, best method for data data is lasso with alpha = 0.01 and mean Error: 0.2167
# Training model on full data
# For year 4, MAE on test set: 0.1566
# For year 4, MSE on test set: 0.0644
# Running linear regression for data type: A
# Mean error for data A and hyperparameter None: 4160421941.0008
# --- 7 milli-seconds ---
# After cross-val for data A mean Error: 4160421941.0008
# Training model on full data
# For year 4, MAE on test set: 0.1718
# For year 4, MSE on test set: 0.0709

# %%
# print('Printing Predictions')
# for y_hat, y in zip(predicted_y, test_y):
#     print(y, y_hat)

# %% [markdown]
# ### Feature Importance based on learned regressor

# %%
for model in [dt_model, lr_model, lm_model]:
    print('\nModel : ', model)
    
    model_select = SelectFromModel(model, prefit=True)
    train_x_df_new = model_select.transform(train_x_df)
    print(train_x_df.shape, train_x_df_new.shape)

    feature_idx = model_select.get_support()
    feature_name = train_x_df.columns[feature_idx]
    print("Important Features: " ,feature_name)
# Out:
# Model :  DecisionTreeRegressor(criterion='mae', max_depth=3)
# (422, 110) (422, 6)
# Important Features:  Index(['OCFt-5', 'Cash+t-5', 'Margin_OCFM', 'Growth_GM', 'Projections_SGrt+1',
#        'Sector_Consumer Cyclical'],
#       dtype='object')
#
# Model :  LinearRegression()
# (422, 110) (422, 2)
# Important Features:  Index(['S t+1', 'Projections_St+1'], dtype='object')
#
# Model :  Ridge(alpha=10)
# (422, 110) (422, 27)
# Important Features:  Index(['SGAt-1', 'SGAt-2', 'OCFt-3', 'OCFt-5', 'CPXt-1', 'CPXt-2', 'CPXt-5',
#        'Cash+t-2', 'Cash+t-5', 'STDt-3', 'VarT', 'VarT+1', 'Srpr1',
#        'Margin_PBTM', 'Margin_EBITDAM', 'Margin_NM', 'Margin_OCFM',
#        'Growth_GM', 'Growth_EBITDAM', 'Projections_SGrt+1',
#        'Sector_Basic Materials', 'Sector_Communication Services',
#        'Sector_Consumer Cyclical', 'Sector_Energy',
#        'Sector_Financial Services', 'Sector_Industrials', 'Sector_Technology'],
#       dtype='object')

# %% [markdown]
# ### Get Nearest Neighbors using KNN

# %%
# Using all_cmp_data (train + test) and standardize it
query = 'TSLA'

print('All data size', all_cmp_data.shape)

this_data = all_cmp_data.loc[query].to_numpy().reshape(1, -1)
this_data = scaler.transform(this_data)


# ensure this is same as in prepare data -- can get indices in train
train_x, _ = train_test_split(all_cmp_data, shuffle=True, test_size=0.3, random_state=15)
train_x = train_x.reset_index()
all_train_tics = train_x['tic']

# returns index in the training set
neighbors = knn_model.kneighbors(this_data, n_neighbors=5, return_distance=False)

print('Neigbors are: ')
for n in neighbors[0]:
    print('Company close to {} is {}'.format(query, all_train_tics[n]))
# Out:
# All data size (603, 110)
# Neigbors are:
# Company close to TSLA is TSLA
# Company close to TSLA is HOFT
# Company close to TSLA is HBI
# Company close to TSLA is MHK
# Company close to TSLA is GPI

# %%
cluster_data = copy.deepcopy(all_cmp_data)
cluster_data = cluster_data.reset_index()
del cluster_data['tic']
X_embedded = TSNE(n_components=2).fit_transform(cluster_data)
print('reduced shape', X_embedded.shape)
# Out:
# reduced shape (603, 2)

# %%
df = pd.DataFrame()
df['a'] = X_embedded[:,0]
df['b'] = X_embedded[:,1]
plt.figure(figsize=(16,10))
sns.scatterplot(
    data=df)

## plot just one year data ##
# Out:
# <AxesSubplot:>
