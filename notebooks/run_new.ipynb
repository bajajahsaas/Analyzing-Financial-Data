# %%
import pandas as pd
import numpy as np
from scipy import stats
import seaborn as sn
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from regression import ridge_and_lasso, decision_trees, k_nearest_neighbors, linear_regression
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_regression, mutual_info_regression
from matplotlib import pyplot
from sklearn.feature_selection import SelectFromModel
from sklearn import preprocessing
from sklearn.preprocessing import OneHotEncoder
import copy
from sklearn.manifold import TSNE
import seaborn as sns

# %%
def read_data(filepath, use_industry=False, replace_with_mean=False):
    data = pd.read_excel(filepath, sheet_name = "Data", headers = None)
    data = data.set_index('tic')
    data.columns = data.columns.map(str)

    

    print('Original data shape: ', data.shape)

    # del columns with all NAN
    data = data.dropna(axis=1, how='all')

    # sector and industry can't be aggregated, drop if NAN
    data = data[pd.notnull(data['Sector'])]

    if use_industry:
        data = data[pd.notnull(data['Industry'])]

    print('Data after removing NAN sectors, industries ', data.shape)
    

    if replace_with_mean: 
        # replace with mean values
        print("Replacing empty cells with column means")
        for col in data.columns.to_list():
            if col == 'Sector':
                continue
            elif use_industry and col == 'Industry':
                continue
            data[col].fillna(data[col].mean(), inplace=True)

    # del rows with any NAN 
    data = data.dropna()

    print("Final Data: ", data.shape)


    # delete future sales predictions
    del data['St+1']
    del data['St']

    # Convert ordinal Sector into one-hot vectors
    data = pd.concat([data,pd.get_dummies(data['Sector'], prefix='Sector',dummy_na=False)],axis=1).drop(['Sector'],axis=1)

    if use_industry:
        # Convert ordinal Sector into one-hot vectors
        data = pd.concat([data,pd.get_dummies(data['Industry'], prefix='Industry',dummy_na=False)],axis=1).drop(['Industry'],axis=1)
    else:
        del data['Industry']

    return data

filepath = "../Sample.2.xlsx"
data = read_data(filepath)
data.head()
# Out:
# Original data shape:  (2559, 55)
# Data after removing NAN sectors, industries  (2396, 55)
# Final Data:  (1634, 55)
#          EMPLt     CPXt-1  GDWLt-1       GPt-1     OCFt-1      PPEt-1   RDt-1  \
# tic
# A      16300.0   156000.0  3590000   2790000.0  1020000.0    850000.0  404000
# AA     13800.0   379000.0   150000   1200000.0   686000.0   7920000.0   27000
# AAL   107400.0  4270000.0  4090000  11420000.0  3820000.0  43730000.0       0
# AAN    12100.0    92960.0   736580   1730000.0   441570.0    566880.0       0
# AAOI    3115.0    29430.0        0     45700.0     -858.0    256330.0   43400
#
#          SGAt-1        St-1     TEQt-1  ...  Sector_Communication Services  \
# tic                                     ...
# A     1860000.0   5160000.0  4750000.0  ...                              0
# AA     307000.0  10500000.0  4110000.0  ...                              0
# AAL   2000000.0  45770000.0  -118000.0  ...                              0
# AAN   1170000.0   3950000.0  1740000.0  ...                              0
# AAOI    94450.0    190870.0   273790.0  ...                              0
#
#       Sector_Consumer Cyclical  Sector_Consumer Defensive  Sector_Energy  \
# tic
# A                            0                          0              0
# AA                           0                          0              0
# AAL                          0                          0              0
# AAN                          0                          0              0
# AAOI                         0                          0              0
#
#       Sector_Financial Services  Sector_Healthcare  Sector_Industrials  \
# tic
# A                             0                  1                   0
# AA                            0                  0                   0
# AAL                           0                  0                   1
# AAN                           0                  0                   1
# AAOI                          0                  0                   0
#
#       Sector_Real Estate  Sector_Technology  Sector_Utilities
# tic
# A                      0                  0                 0
# AA                     0                  0                 0
# AAL                    0                  0                 0
# AAN                    0                  0                 0
# AAOI                   0                  1                 0
#
# [5 rows x 62 columns]

# %%
def split_data(data, year):
    year_cols = ['EMPLt']

    for col in data.columns.to_list():
        if col.endswith(str(year)) or col.startswith('Sector') or col.startswith('Industry'):
            year_cols.append(col)

    # print(year, year_cols)
    year_df = data[year_cols].copy()
    year_df['Gt-' + str(year)] = data['St-' + str(year)] * 1.0 / data['St-' + str(year + 1)]
    print(year, year_df.columns.to_list())

    # delete sales from training data as output_var is Gt
    del year_df['St-'+ str(year)]
    return year_df

years = [1, 2, 3, 4]
# year = 1 means to predict Gt-1 (St-1/St-2)

all_df = {}
for year in years:
    all_df[year] = split_data(data, year)
    print(year, all_df[year].shape)
# Out:
# 1 ['EMPLt', 'CPXt-1', 'GDWLt-1', 'GPt-1', 'OCFt-1', 'PPEt-1', 'RDt-1', 'SGAt-1', 'St-1', 'TEQt-1', 'TDt-1', 'Sector_Basic Materials', 'Sector_Communication Services', 'Sector_Consumer Cyclical', 'Sector_Consumer Defensive', 'Sector_Energy', 'Sector_Financial Services', 'Sector_Healthcare', 'Sector_Industrials', 'Sector_Real Estate', 'Sector_Technology', 'Sector_Utilities', 'Gt-1']
# 1 (1634, 22)
# 2 ['EMPLt', 'CPXt-2', 'GDWLt-2', 'GPt-2', 'OCFt-2', 'PPEt-2', 'RDt-2', 'SGAt-2', 'St-2', 'TEQt-2', 'TDt-2', 'Sector_Basic Materials', 'Sector_Communication Services', 'Sector_Consumer Cyclical', 'Sector_Consumer Defensive', 'Sector_Energy', 'Sector_Financial Services', 'Sector_Healthcare', 'Sector_Industrials', 'Sector_Real Estate', 'Sector_Technology', 'Sector_Utilities', 'Gt-2']
# 2 (1634, 22)
# 3 ['EMPLt', 'CPXt-3', 'GDWLt-3', 'GPt-3', 'OCFt-3', 'PPEt-3', 'RDt-3', 'SGAt-3', 'St-3', 'TEQt-3', 'TDt-3', 'Sector_Basic Materials', 'Sector_Communication Services', 'Sector_Consumer Cyclical', 'Sector_Consumer Defensive', 'Sector_Energy', 'Sector_Financial Services', 'Sector_Healthcare', 'Sector_Industrials', 'Sector_Real Estate', 'Sector_Technology', 'Sector_Utilities', 'Gt-3']
# 3 (1634, 22)
# 4 ['EMPLt', 'CPXt-4', 'GDWLt-4', 'GPt-4', 'OCFt-4', 'PPEt-4', 'RDt-4', 'SGAt-4', 'St-4', 'TEQt-4', 'TDt-4', 'Sector_Basic Materials', 'Sector_Communication Services', 'Sector_Consumer Cyclical', 'Sector_Consumer Defensive', 'Sector_Energy', 'Sector_Financial Services', 'Sector_Healthcare', 'Sector_Industrials', 'Sector_Real Estate', 'Sector_Technology', 'Sector_Utilities', 'Gt-4']
# 4 (1634, 22)

# %%
all_df_list = []
for year in years:
    temp_df = all_df[year].copy(deep=True)
    all_df_list.append(temp_df)

first_year = 0
suffix_str = '1' # at end of col names
for i in range(1, len(all_df_list)):
    all_df_list[i].columns = all_df_list[first_year].columns


merged_df = pd.concat(all_df_list, ignore_index=False)
print('Size of merged dataset : ', merged_df.shape)

# year == 0 means merged dataset for all years, train a single model for all years
rename_columns = {}
for col in merged_df.columns.to_list():
    if col.endswith(suffix_str):
        newcol = col[:-1] + str(0)
        rename_columns[col] = newcol
merged_df.rename(columns=rename_columns, inplace=True)
all_df[0] = merged_df
years.append(0)
# Out:
# Size of merged dataset :  (6536, 22)

# %%
merged_df
# Out:
#          EMPLt     CPXt-0  GDWLt-0       GPt-0     OCFt-0      PPEt-0   RDt-0  \
# tic
# A      16300.0   156000.0  3590000   2790000.0  1020000.0    850000.0  404000
# AA     13800.0   379000.0   150000   1200000.0   686000.0   7920000.0   27000
# AAL   107400.0  4270000.0  4090000  11420000.0  3820000.0  43730000.0       0
# AAN    12100.0    92960.0   736580   1730000.0   441570.0    566880.0       0
# AAOI    3115.0    29430.0        0     45700.0     -858.0    256330.0   43400
# ...        ...        ...      ...         ...        ...         ...     ...
# ZIXI     566.0     2140.0     2160     49610.0    15250.0      3980.0    9550
# ZNGA    1883.0    10310.0   613340    502870.0    60020.0    269440.0  329300
# ZS      2020.0     8170.0        0     98250.0    -6020.0     13140.0   33560
# ZTS    10600.0   216000.0  1480000   3140000.0   713000.0   1380000.0  376000
# ZUMZ    2575.0    20400.0    56000    249060.0    48460.0    129650.0       0
#
#          SGAt-0     TEQt-0     TDt-0  ...  Sector_Consumer Cyclical  \
# tic                                   ...
# A     1860000.0  4750000.0   1790000  ...                         0
# AA     307000.0  4110000.0   1961000  ...                         0
# AAL   2000000.0  -118000.0  30590000  ...                         0
# AAN   1170000.0  1740000.0    708410  ...                         0
# AAOI    94450.0   273790.0    108960  ...                         0
# ...         ...        ...       ...  ...                       ...
# ZIXI    40300.0    49070.0         0  ...                         0
# ZNGA   603650.0  1580000.0         0  ...                         0
# ZS     133320.0    57710.0         0  ...                         0
# ZTS   1740000.0  1490000.0   4470000  ...                         0
# ZUMZ   207420.0   307050.0         0  ...                         1
#
#       Sector_Consumer Defensive  Sector_Energy  Sector_Financial Services  \
# tic
# A                             0              0                          0
# AA                            0              0                          0
# AAL                           0              0                          0
# AAN                           0              0                          0
# AAOI                          0              0                          0
# ...                         ...            ...                        ...
# ZIXI                          0              0                          0
# ZNGA                          0              0                          0
# ZS                            0              0                          0
# ZTS                           0              0                          0
# ZUMZ                          0              0                          0
#
#       Sector_Healthcare  Sector_Industrials  Sector_Real Estate  \
# tic
# A                     1                   0                   0
# AA                    0                   0                   0
# AAL                   0                   1                   0
# AAN                   0                   1                   0
# AAOI                  0                   0                   0
# ...                 ...                 ...                 ...
# ZIXI                  0                   0                   0
# ZNGA                  0                   0                   0
# ZS                    0                   0                   0
# ZTS                   1                   0                   0
# ZUMZ                  0                   0                   0
#
#       Sector_Technology  Sector_Utilities      Gt-0
# tic
# A                     0                 0  1.050916
# AA                    0                 0  0.776627
# AAL                   0                 0  1.027616
# AAN                   0                 0  1.031332
# AAOI                  1                 0  0.713613
# ...                 ...               ...       ...
# ZIXI                  1                 0  1.099251
# ZNGA                  0                 0  0.969531
# ZS                    1                 0  1.565044
# ZTS                   0                 0  1.025157
# ZUMZ                  0                 0  1.039904
#
# [6536 rows x 22 columns]

# %% [markdown]
# ## Regression Models

# %%
def prepare_data(X, year):
    X = X.reset_index()
    del X['tic']
    
    Y = X['Gt-' + str(year)]
    del X['Gt-' + str(year)]
    train_x, test_x, train_y, test_y = train_test_split(X, Y, shuffle=True, test_size=0.3, random_state=15)

    return train_x, train_y, test_x, test_y

# %%
scalers = {}

def standardize_data(train_x_df, train_y_df, test_x_df, test_y_df, year):
    # Requires numpy array for cross-validation in regression.py
    train_x = train_x_df.to_numpy()
    test_x = test_x_df.to_numpy()
    train_y = train_y_df.to_numpy()
    test_y = test_y_df.to_numpy()

    print('Train=', train_x.shape)
    print('Test=', test_x.shape)

    # normalize and scale data attributes
    # use only train_x for fitting
    # don't normalize, scale output variable

    scaler = preprocessing.MinMaxScaler().fit(train_x)

    train_x = scaler.transform(train_x)
    test_x = scaler.transform(test_x)

    # to be used later for query
    scalers[year] = scaler
    return train_x, train_y, test_x, test_y

# %%
train_x_dfs = {}
train_y_dfs = {}
test_x_dfs = {}
test_y_dfs = {}

train_xs = {}
train_ys = {}
test_xs = {}
test_ys= {}

for year in years:
    print('Preparing data for year: ', year)
    print(all_df[year].columns.to_list())
    train_x_dfs[year], train_y_dfs[year], test_x_dfs[year], test_y_dfs[year] = prepare_data(all_df[year], year)
    train_xs[year], train_ys[year], test_xs[year], test_ys[year] = standardize_data(train_x_dfs[year], train_y_dfs[year], test_x_dfs[year], test_y_dfs[year], year)
# Out:
# Preparing data for year:  1
# ['EMPLt', 'CPXt-1', 'GDWLt-1', 'GPt-1', 'OCFt-1', 'PPEt-1', 'RDt-1', 'SGAt-1', 'TEQt-1', 'TDt-1', 'Sector_Basic Materials', 'Sector_Communication Services', 'Sector_Consumer Cyclical', 'Sector_Consumer Defensive', 'Sector_Energy', 'Sector_Financial Services', 'Sector_Healthcare', 'Sector_Industrials', 'Sector_Real Estate', 'Sector_Technology', 'Sector_Utilities', 'Gt-1']
# Train= (1143, 21)
# Test= (491, 21)
# Preparing data for year:  2
# ['EMPLt', 'CPXt-2', 'GDWLt-2', 'GPt-2', 'OCFt-2', 'PPEt-2', 'RDt-2', 'SGAt-2', 'TEQt-2', 'TDt-2', 'Sector_Basic Materials', 'Sector_Communication Services', 'Sector_Consumer Cyclical', 'Sector_Consumer Defensive', 'Sector_Energy', 'Sector_Financial Services', 'Sector_Healthcare', 'Sector_Industrials', 'Sector_Real Estate', 'Sector_Technology', 'Sector_Utilities', 'Gt-2']
# Train= (1143, 21)
# Test= (491, 21)
# Preparing data for year:  3
# ['EMPLt', 'CPXt-3', 'GDWLt-3', 'GPt-3', 'OCFt-3', 'PPEt-3', 'RDt-3', 'SGAt-3', 'TEQt-3', 'TDt-3', 'Sector_Basic Materials', 'Sector_Communication Services', 'Sector_Consumer Cyclical', 'Sector_Consumer Defensive', 'Sector_Energy', 'Sector_Financial Services', 'Sector_Healthcare', 'Sector_Industrials', 'Sector_Real Estate', 'Sector_Technology', 'Sector_Utilities', 'Gt-3']
# Train= (1143, 21)
# Test= (491, 21)
# Preparing data for year:  4
# ['EMPLt', 'CPXt-4', 'GDWLt-4', 'GPt-4', 'OCFt-4', 'PPEt-4', 'RDt-4', 'SGAt-4', 'TEQt-4', 'TDt-4', 'Sector_Basic Materials', 'Sector_Communication Services', 'Sector_Consumer Cyclical', 'Sector_Consumer Defensive', 'Sector_Energy', 'Sector_Financial Services', 'Sector_Healthcare', 'Sector_Industrials', 'Sector_Real Estate', 'Sector_Technology', 'Sector_Utilities', 'Gt-4']
# Train= (1143, 21)
# Test= (491, 21)
# Preparing data for year:  0
# ['EMPLt', 'CPXt-0', 'GDWLt-0', 'GPt-0', 'OCFt-0', 'PPEt-0', 'RDt-0', 'SGAt-0', 'TEQt-0', 'TDt-0', 'Sector_Basic Materials', 'Sector_Communication Services', 'Sector_Consumer Cyclical', 'Sector_Consumer Defensive', 'Sector_Energy', 'Sector_Financial Services', 'Sector_Healthcare', 'Sector_Industrials', 'Sector_Real Estate', 'Sector_Technology', 'Sector_Utilities', 'Gt-0']
# Train= (4575, 21)
# Test= (1961, 21)

# %% [markdown]
# ### Feature Selection

# %%
# feature selection
def select_features(X_train, y_train, X_test, mode):
    # configure to select all features
    if mode == 'f_regression':
        fs = SelectKBest(score_func=f_regression, k='all')
    elif mode == 'mutual_info_regression':
        fs = SelectKBest(score_func=mutual_info_regression, k='all')
    # learn relationship from training data
    X_train = X_train.astype(np.float64)
    y_train = y_train.astype(np.float64)
    X_test = X_test.astype(np.float64)
    fs.fit(X_train, y_train)
    # transform train input data
    X_train_fs = fs.transform(X_train)
    # transform test input data
    X_test_fs = fs.transform(X_test)
    
    return X_train_fs, X_test_fs, fs

modes = ['f_regression', 'mutual_info_regression']
for year in years:
    for mode in modes:
        # feature selection
        X_train_fs, X_test_fs, fs = select_features(train_x_dfs[year], train_y_dfs[year], test_x_dfs[year], mode)

        # what are scores for the features
        # for i in range(len(fs.scores_)):
        # 	print('Feature %d: %f' % (i, fs.scores_[i]))

        # plot the scores
        columns = train_x_dfs[year].columns.to_list()
        pyplot.xticks(rotation = (45), fontsize = 2)
        pyplot.bar([i for i in range(len(fs.scores_))], fs.scores_, tick_label=columns)
        pyplot.xlabel("Features")
        pyplot.ylabel("Important")
        pyplot.title("Year: {}, mode : {}".format(year, mode))
        pyplot.show()

# %% [markdown]
# ### Regression Model

# %%
# Compute MAE
def compute_error(y_hat, y):
    # mean absolute error
    return np.abs(y_hat - y).mean()

# Compute MSE
def compute_MSE(y, y_hat):
    # mean squared error
    return np.mean(np.power(y - y_hat, 2))

# %%
predicted_y  = {}
dt_model = {}
knn_model = {}
lr_model = {}
lm_model = {}

for year in years:
    metrics = ['mae', 'mse']
    models = ['dt', 'knn', 'lm', 'lr']
    print("\n")
    print("+++++++++++++")
    print("year: " + str(year))
    print("+++++++++++++")
    print(train_xs[year].shape, train_ys[year].shape, test_xs[year].shape)
    for model in models:
        if model == 'dt':
            predicted_y[year], dt_model[year] = decision_trees('A', train_xs[year], train_ys[year], test_xs[year])
        elif model =='knn':
            predicted_y[year], knn_model[year] = k_nearest_neighbors('A', train_xs[year], train_ys[year], test_xs[year])
        elif model =='lr':
            predicted_y[year], lr_model[year] = linear_regression('A', train_xs[year], train_ys[year], test_xs[year])
        elif model == 'lm':
            predicted_y[year], lm_model[year] = ridge_and_lasso('data', train_xs[year], train_ys[year], test_xs[year])
            
        for metric in metrics:
            if metric == 'mae':
                print('For year {}, MAE on test set: {:0.4f}'.format(str(year), compute_error(predicted_y[year], test_ys[year])))
            elif metric == 'mse':
                print('For year {}, MSE on test set: {:0.4f}'.format(str(year), compute_MSE(predicted_y[year], test_ys[year])))
# Out:
# +++++++++++++
# year: 1
# +++++++++++++
# (1143, 21) (1143,) (491, 21)
# Running decision tree regressor for data type: A
# After cross-val, best depth for data A is 3 with mean Error: 0.1663
# Training model on full data
# For year 1, MAE on test set: 0.1359
# For year 1, MSE on test set: 0.0663
# Running k-nearest neighbor regressor for data type: A
# After cross-val, best neighbors for data A is 25 with mean Error: 0.1864
# Training model on full data
# For year 1, MAE on test set: 0.1519
# For year 1, MSE on test set: 0.0677
# Running ridge regressors for data type: data
# Running lasso regressors for data type: data
# After cross-val, best method for data data is lasso with alpha = 0.01 and mean Error: 0.1795
# Training model on full data
# For year 1, MAE on test set: 0.1495
# For year 1, MSE on test set: 0.0629
# Running linear regression for data type: A
# After cross-val for data A mean Error: 19071535243.3709
# Training model on full data
# For year 1, MAE on test set: 0.1544
# For year 1, MSE on test set: 0.0643
#
#
# +++++++++++++
# year: 2
# +++++++++++++
# (1143, 21) (1143,) (491, 21)
# Running decision tree regressor for data type: A
# After cross-val, best depth for data A is 3 with mean Error: 0.1681
# Training model on full data
# For year 2, MAE on test set: 0.1460
# For year 2, MSE on test set: 0.0669
# Running k-nearest neighbor regressor for data type: A
# After cross-val, best neighbors for data A is 25 with mean Error: 0.1818
# Training model on full data
# For year 2, MAE on test set: 0.1621
# For year 2, MSE on test set: 0.0753
# Running ridge regressors for data type: data
# Running lasso regressors for data type: data
# After cross-val, best method for data data is ridge with alpha = 10 and mean Error: 0.1788
# Training model on full data
# For year 2, MAE on test set: 0.1591
# For year 2, MSE on test set: 0.0696
# Running linear regression for data type: A
# After cross-val for data A mean Error: 0.1809
# Training model on full data
# For year 2, MAE on test set: 0.1648
# For year 2, MSE on test set: 0.0715
#
#
# +++++++++++++
# year: 3
# +++++++++++++
# (1143, 21) (1143,) (491, 21)
# Running decision tree regressor for data type: A
# After cross-val, best depth for data A is 3 with mean Error: 0.2144
# Training model on full data
# For year 3, MAE on test set: 0.1749
# For year 3, MSE on test set: 0.2347
# Running k-nearest neighbor regressor for data type: A
# After cross-val, best neighbors for data A is 20 with mean Error: 0.2196
# Training model on full data
# For year 3, MAE on test set: 0.2173
# For year 3, MSE on test set: 0.2704
# Running ridge regressors for data type: data
# Running lasso regressors for data type: data
# After cross-val, best method for data data is ridge with alpha = 10 and mean Error: 0.2230
# Training model on full data
# For year 3, MAE on test set: 0.1971
# For year 3, MSE on test set: 0.2274
# Running linear regression for data type: A
# After cross-val for data A mean Error: 0.2578
# Training model on full data
# For year 3, MAE on test set: 0.1985
# For year 3, MSE on test set: 0.2276
#
#
# +++++++++++++
# year: 4
# +++++++++++++
# (1143, 21) (1143,) (491, 21)
# Running decision tree regressor for data type: A
# After cross-val, best depth for data A is 3 with mean Error: 0.2136
# Training model on full data
# For year 4, MAE on test set: 0.2225
# For year 4, MSE on test set: 0.5164
# Running k-nearest neighbor regressor for data type: A
# After cross-val, best neighbors for data A is 20 with mean Error: 0.2157
# Training model on full data
# For year 4, MAE on test set: 0.2456
# For year 4, MSE on test set: 0.5227
# Running ridge regressors for data type: data
# Running lasso regressors for data type: data
# After cross-val, best method for data data is lasso with alpha = 0.01 and mean Error: 0.2167
# Training model on full data
# For year 4, MAE on test set: 0.2386
# For year 4, MSE on test set: 0.5107
# Running linear regression for data type: A
# After cross-val for data A mean Error: 0.2239
# Training model on full data
# For year 4, MAE on test set: 0.2388
# For year 4, MSE on test set: 0.5027
#
#
# +++++++++++++
# year: 0
# +++++++++++++
# (4575, 21) (4575,) (1961, 21)
# Running decision tree regressor for data type: A
# After cross-val, best depth for data A is 3 with mean Error: 0.1767
# Training model on full data
# For year 0, MAE on test set: 0.1871
# For year 0, MSE on test set: 0.3199
# Running k-nearest neighbor regressor for data type: A
# After cross-val, best neighbors for data A is 25 with mean Error: 0.1946
# Training model on full data
# For year 0, MAE on test set: 0.2029
# For year 0, MSE on test set: 0.3260
# Running ridge regressors for data type: data
# Running lasso regressors for data type: data
# After cross-val, best method for data data is ridge with alpha = 10 and mean Error: 0.1949
# Training model on full data
# For year 0, MAE on test set: 0.2049
# For year 0, MSE on test set: 0.3131
# Running linear regression for data type: A
# After cross-val for data A mean Error: 0.1960
# Training model on full data
# For year 0, MAE on test set: 0.2053
# For year 0, MSE on test set: 0.3131

# %%
# print('Printing Predictions')
# for y_hat, y in zip(predicted_y, test_y):
#     print(y, y_hat)

# %% [markdown]
# ### Feature Importance based on learned regressor

# %%
for year in years:
    print("\n")
    print("+++++++++++++")
    print("year: " + str(year))
    print("+++++++++++++")
    for model in [dt_model[year], lr_model[year], lm_model[year]]:
        print('\nModel : ', model)
        
        model_select = SelectFromModel(model, prefit=True)
        train_x_df_new = model_select.transform(train_x_dfs[year])
        print(train_x_dfs[year].shape, train_x_df_new.shape)

        feature_idx = model_select.get_support()
        feature_name = train_x_dfs[year].columns[feature_idx]
        print("Important Features: " ,feature_name)
# Out:
# +++++++++++++
# year: 1
# +++++++++++++
#
# Model :  DecisionTreeRegressor(criterion='mae', max_depth=3)
# (1143, 21) (1143, 6)
# Important Features:  Index(['EMPLt', 'GPt-1', 'OCFt-1', 'PPEt-1', 'RDt-1', 'TEQt-1'], dtype='object')
#
# Model :  LinearRegression()
# (1143, 21) (1143, 7)
# Important Features:  Index(['EMPLt', 'CPXt-1', 'GPt-1', 'OCFt-1', 'PPEt-1', 'TEQt-1', 'TDt-1'], dtype='object')
#
# Model :  Lasso(alpha=0.01)
# (1143, 21) (1143, 1)
# Important Features:  Index(['Sector_Healthcare'], dtype='object')
#
#
# +++++++++++++
# year: 2
# +++++++++++++
#
# Model :  DecisionTreeRegressor(criterion='mae', max_depth=3)
# (1143, 21) (1143, 4)
# Important Features:  Index(['EMPLt', 'GDWLt-2', 'GPt-2', 'Sector_Energy'], dtype='object')
#
# Model :  LinearRegression()
# (1143, 21) (1143, 11)
# Important Features:  Index(['Sector_Basic Materials', 'Sector_Communication Services',
#        'Sector_Consumer Cyclical', 'Sector_Consumer Defensive',
#        'Sector_Energy', 'Sector_Financial Services', 'Sector_Healthcare',
#        'Sector_Industrials', 'Sector_Real Estate', 'Sector_Technology',
#        'Sector_Utilities'],
#       dtype='object')
#
# Model :  Ridge(alpha=10)
# (1143, 21) (1143, 9)
# Important Features:  Index(['EMPLt', 'CPXt-2', 'TDt-2', 'Sector_Consumer Cyclical',
#        'Sector_Consumer Defensive', 'Sector_Energy',
#        'Sector_Financial Services', 'Sector_Healthcare', 'Sector_Utilities'],
#       dtype='object')
#
#
# +++++++++++++
# year: 3
# +++++++++++++
#
# Model :  DecisionTreeRegressor(criterion='mae', max_depth=3)
# (1143, 21) (1143, 6)
# Important Features:  Index(['EMPLt', 'CPXt-3', 'PPEt-3', 'SGAt-3', 'TDt-3', 'Sector_Energy'], dtype='object')
#
# Model :  LinearRegression()
# (1143, 21) (1143, 8)
# Important Features:  Index(['EMPLt', 'GPt-3', 'OCFt-3', 'PPEt-3', 'RDt-3', 'SGAt-3', 'TEQt-3',
#        'TDt-3'],
#       dtype='object')
#
# Model :  Ridge(alpha=10)
# (1143, 21) (1143, 7)
# Important Features:  Index(['GDWLt-3', 'TDt-3', 'Sector_Consumer Cyclical',
#        'Sector_Consumer Defensive', 'Sector_Energy', 'Sector_Healthcare',
#        'Sector_Industrials'],
#       dtype='object')
#
#
# +++++++++++++
# year: 4
# +++++++++++++
#
# Model :  DecisionTreeRegressor(criterion='mae', max_depth=3)
# (1143, 21) (1143, 6)
# Important Features:  Index(['EMPLt', 'OCFt-4', 'PPEt-4', 'RDt-4', 'TDt-4', 'Sector_Energy'], dtype='object')
#
# Model :  LinearRegression()
# (1143, 21) (1143, 11)
# Important Features:  Index(['Sector_Basic Materials', 'Sector_Communication Services',
#        'Sector_Consumer Cyclical', 'Sector_Consumer Defensive',
#        'Sector_Energy', 'Sector_Financial Services', 'Sector_Healthcare',
#        'Sector_Industrials', 'Sector_Real Estate', 'Sector_Technology',
#        'Sector_Utilities'],
#       dtype='object')
#
# Model :  Lasso(alpha=0.01)
# (1143, 21) (1143, 2)
# Important Features:  Index(['Sector_Energy', 'Sector_Healthcare'], dtype='object')
#
#
# +++++++++++++
# year: 0
# +++++++++++++
#
# Model :  DecisionTreeRegressor(criterion='mae', max_depth=3)
# (4575, 21) (4575, 5)
# Important Features:  Index(['EMPLt', 'GPt-0', 'PPEt-0', 'RDt-0', 'Sector_Technology'], dtype='object')
#
# Model :  LinearRegression()
# (4575, 21) (4575, 9)
# Important Features:  Index(['EMPLt', 'CPXt-0', 'GPt-0', 'OCFt-0', 'PPEt-0', 'RDt-0', 'SGAt-0',
#        'TEQt-0', 'TDt-0'],
#       dtype='object')
#
# Model :  Ridge(alpha=10)
# (4575, 21) (4575, 10)
# Important Features:  Index(['EMPLt', 'GDWLt-0', 'RDt-0', 'TDt-0', 'Sector_Communication Services',
#        'Sector_Consumer Cyclical', 'Sector_Financial Services',
#        'Sector_Healthcare', 'Sector_Industrials', 'Sector_Utilities'],
#       dtype='object')

# %%
# Using all_cmp_data (train + test) and standardize it
year = 1
query = 'TSLA'
all_cmp_data = all_df[year].copy(deep=True)
# remove output var
del all_cmp_data['Gt-'+str(year)]

# %% [markdown]
# ### Get Nearest Neighbors using KNN

# %%
print('All data size', all_cmp_data.shape)
this_data = all_cmp_data.loc[query].to_numpy().reshape(1, -1)
this_data = scalers[year].transform(this_data)


# ensure this is same as in prepare data -- can get indices in train
train_x, _ = train_test_split(all_cmp_data, shuffle=True, test_size=0.3, random_state=15)
train_x = train_x.reset_index()
all_train_tics = train_x['tic']

# returns index in the training set
neighbors = knn_model[year].kneighbors(this_data, n_neighbors=5, return_distance=False)

print('Neigbors are: ')
for n in neighbors[0]:
    print('Company close to {} is {}'.format(query, all_train_tics[n]))
# Out:
# All data size (1634, 21)
# Neigbors are:
# Company close to TSLA is TSLA
# Company close to TSLA is GT
# Company close to TSLA is WYNN
# Company close to TSLA is NCLH
# Company close to TSLA is LB

# %% [markdown]
# ### Clustering

# %%
cluster_data = copy.deepcopy(all_cmp_data)
cluster_data = cluster_data.reset_index()
del cluster_data['tic']
X_embedded = TSNE(n_components=2).fit_transform(cluster_data)
print('reduced shape', X_embedded.shape)
# Out:
# reduced shape (1634, 2)

# %%
df = pd.DataFrame()
df['a'] = X_embedded[:,0]
df['b'] = X_embedded[:,1]
plt.figure(figsize=(16,10))
sns.scatterplot(
    data=df)
# Out:
# <AxesSubplot:>
